# %%
# %pip install mysql-connector-python
# %pip install Faker

import mysql.connector
from faker import Faker
import random
import pandas as pd


def create_load_data():
    """Connexion to MySQL""" 
    bd_hevia = mysql.connector.connect(
        host="localhost",
        port=3306,
        user="hevia",
        password="hevia",
        database="mysql_hevia"
    )

    bd_joboard = mysql.connector.connect(
        host="localhost",
        port=3307,
        user="hevia",
        password="hevia",
        database="mysql_joboard"
    )
    cursor_hevia = bd_hevia.cursor()
    cursor_joboard = bd_joboard.cursor()
    print(bd_hevia)
    print(bd_joboard)
    print("✅ Connecté à MySQL avec succès")

 

    create_query =  [
        """
        CREATE TABLE IF NOT EXISTS users (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(100),
            email VARCHAR(100) UNIQUE,
            role VARCHAR(100)  NOT NULL  
        )
        """, 
        """
        CREATE TABLE IF NOT EXISTS companies (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(100),
            location VARCHAR(100)
        )
        """,
        """
        CREATE TABLE IF NOT EXISTS categories (
            id INT AUTO_INCREMENT PRIMARY KEY,
            name VARCHAR(100)
        )
        """,
        """
        CREATE TABLE IF NOT EXISTS jobs (
            id INT AUTO_INCREMENT PRIMARY KEY,
            title VARCHAR(100),
            description TEXT,
            location VARCHAR(100),
            company_id INT,
            category_id INT,
            FOREIGN KEY (company_id) REFERENCES companies(id),
            FOREIGN KEY (category_id) REFERENCES categories(id)
        )
        """,
        """
        CREATE TABLE IF NOT EXISTS applications (
            id INT AUTO_INCREMENT PRIMARY KEY,
            user_id INT,
            job_id INT,
            cover_letter TEXT,
            date_applied DATE,
            FOREIGN KEY (user_id) REFERENCES users(id),
            FOREIGN KEY (job_id) REFERENCES jobs(id)
        )
        """,

    ]
   
    for query in create_query:
        cursor_hevia.execute(query)
        cursor_joboard.execute(query)


    bd_hevia.commit()
    bd_joboard.commit()
    print("✅ Tables created successfully")


    insert_users = "INSERT INTO users (name, email, role) VALUES (%s, %s, %s)"
    users = [
        ("Alice Dupont", "alice@gmail.com", "candidate"),
        ("Bob Martin", "bob@gmail.com", "candidate"),
        ("Caroline Dubois", "caroline@recrutech.com", "recruiter"),
        ("Daniel Lemoine", "daniel@talentify.io", "recruiter"),
    ]
    cursor_hevia.executemany(insert_users, users)
    bd_hevia.commit()
    print("✅ Users inserted successfully")


    insert_companies = "INSERT INTO companies (name, location) VALUES (%s, %s)"
    companies = [
        ("Tech Innovators", "Paris"),
        ("Recrutech Solutions", "Lyon"),
        ("Talentify", "Marseille"),
    ]           
    cursor_hevia.executemany(insert_companies, companies)
    bd_hevia.commit()
    print("✅ Companies inserted successfully")


    insert_categories = "INSERT INTO categories (name) VALUES (%s)"
    categories = [
        ("Développement Web",),
        ("Marketing Digital",),
        ("Data Science",),
        ("Ressources Humaines",)
    ]
    cursor_hevia.executemany(insert_categories,categories)
    bd_hevia.commit()
    print("✅ Categories inserted successfully")


    insert_jobs = """
    INSERT INTO jobs (title, description, location, company_id, category_id)
    VALUES (%s, %s, %s, %s, %s)
    """
    jobs = [
        ("Développeur Python", "Poste full remote", "Remote", 1, 1),
        ("Chargé de Marketing", "SEO/SEA + contenus", "Lyon", 2, 2),
        ("Data Analyst Junior", "Analyse des données clients", "Paris", 1, 3),
    ]
    cursor_hevia.executemany(insert_jobs, jobs)
    bd_hevia.commit()
    print("✅ Jobs inserted successfully")



    insert_applications= """
    INSERT INTO applications (user_id, job_id, cover_letter, date_applied)
    VALUES (%s, %s, %s, %s)
    """
    applications = [
        (1, 1, "Je suis passionné par le développement Python.", "2025-07-01"),
        (2, 3, "J’ai une forte appétence pour les données.", "2025-07-02"),
    ]
    cursor_hevia.executemany(insert_applications, applications)
    bd_hevia.commit()
    print("✅  Applications inserted successfully")


    print("Data from hevia database:")
    cursor_hevia.execute("SELECT * FROM users")
    print("Users:", cursor_hevia.fetchall())

    cursor_hevia.execute("SELECT * FROM jobs")
    print("Jobs:", cursor_hevia.fetchall())

    cursor_hevia.execute("SELECT * FROM companies")
    print("Companies:", cursor_hevia.fetchall())

    cursor_hevia.execute("SELECT * FROM categories")
    print("Categories:", cursor_hevia.fetchall())

    cursor_hevia.execute("SELECT * FROM applications")
    print("Applications:", cursor_hevia.fetchall())


    tables =['applications', 'categories', 'companies', 'jobs', 'users']


    for table in tables:
        print(table)
        cursor_hevia.execute(f"SELECT * FROM {table}")
        results = cursor_hevia.fetchall()
        columns = [i[0] for i in cursor_hevia.description]
        if 'id' in columns:
            columns_no_id = [col for col in columns if col != 'id']
            job_df = pd.DataFrame(results, columns=columns)
            data = job_df[columns_no_id].values.tolist()
            columns_sql = ", ".join(columns_no_id)
            values = ", ".join(["%s"] * len(columns_no_id))
        else:
            job_df = pd.DataFrame(results, columns=columns)
            data = job_df.values.tolist()
            columns_sql = ", ".join(columns)
            values = ", ".join(["%s"] * len(columns))
        query = f"INSERT INTO {table} ({columns_sql}) VALUES ({values})"
        try:
            cursor_joboard.executemany(query, data)
            bd_joboard.commit()
            print(f"✅ Data copied sucessful to the bd Jobboard for table {table}.")
        except Exception as e:
            print(f"❌ Error, table copy lost  {table}: {e}")

    cursor_hevia.close()
    cursor_joboard.close()
    bd_hevia.close()
    bd_joboard.close()
    print("✅ Connections closed successfully.")
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\fabiola\anaconda3\envs\python1ve\lib\site-packages (9.4.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: Faker in c:\users\fabiola\anaconda3\envs\python1ve\lib\site-packages (37.5.3)
# Requirement already satisfied: tzdata in c:\users\fabiola\anaconda3\envs\python1ve\lib\site-packages (from Faker) (2023.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# La fonction create_load_data() établit une connexion aux bases de données MySQL Hevia et Jobboard.
# Elle crée les tables Users, Categories, Companies, Jobs et Applications.
# Ensuite, elle insère les données dans la base Hevia, puis effectue une copie de ces données vers la base Jobboard.

# %%
create_load_data()
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001893E503ED0>
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000001893E5039D0>
# ✅ Connecté à MySQL avec succès
# ✅ Tables created successfully
# ✅ Users inserted successfully
# ✅ Companies inserted successfully
# ✅ Categories inserted successfully
# ✅ Jobs inserted successfully
# ✅  Applications inserted successfully
# Data from hevia database:
# Users: [(5, 'Alice Dupont', 'alice@gmail.com', 'candidate'), (6, 'Bob Martin', 'bob@gmail.com', 'candidate'), (7, 'Caroline Dubois', 'caroline@recrutech.com', 'recruiter'), (8, 'Daniel Lemoine', 'daniel@talentify.io', 'recruiter'), (9, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (10, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (11, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (12, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (13, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (14, 'John Underwood', 'ysantos@example.com', 'candidate'), (15, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (16, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (17, 'John Underwood', 'ysantos@example.com', 'candidate'), (18, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (19, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (20, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (21, 'John Underwood', 'ysantos@example.com', 'candidate'), (22, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (23, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (24, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (25, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (26, 'John Underwood', 'ysantos@example.com', 'candidate'), (27, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (28, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (29, 'Brian Anderson', 'wcruz@example.org', 'candidate'), (30, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (31, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (32, 'John Underwood', 'ysantos@example.com', 'candidate'), (33, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (34, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (35, 'Brian Anderson', 'wcruz@example.org', 'candidate'), (36, 'Angela Edwards', 'hedwards@example.org', 'recruiter'), (37, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (38, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (39, 'John Underwood', 'ysantos@example.com', 'candidate'), (40, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (41, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (42, 'Brian Anderson', 'wcruz@example.org', 'candidate'), (43, 'Angela Edwards', 'hedwards@example.org', 'recruiter'), (44, 'Heather Russell', 'kylewhite@example.org', 'candidate'), (45, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (46, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (47, 'John Underwood', 'ysantos@example.com', 'candidate'), (48, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (49, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (50, 'Brian Anderson', 'wcruz@example.org', 'candidate'), (51, 'Angela Edwards', 'hedwards@example.org', 'recruiter'), (52, 'Heather Russell', 'kylewhite@example.org', 'candidate'), (53, 'Darren Hunt', 'jessicawiggins@example.com', 'candidate'), (54, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (55, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (56, 'John Underwood', 'ysantos@example.com', 'candidate'), (57, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (58, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (59, 'Brian Anderson', 'wcruz@example.org', 'candidate'), (60, 'Angela Edwards', 'hedwards@example.org', 'recruiter'), (61, 'Heather Russell', 'kylewhite@example.org', 'candidate'), (62, 'Darren Hunt', 'jessicawiggins@example.com', 'candidate'), (63, 'Chelsea Pierce', 'longkristine@example.org', 'recruiter'), (64, 'Maria Robinson', 'daniellegomez@example.org', 'candidate'), (65, 'Steven Olson', 'whitakermary@example.org', 'recruiter'), (66, 'John Underwood', 'ysantos@example.com', 'candidate'), (67, 'Paul Clark', 'amymendoza@example.org', 'candidate'), (68, 'Diana Ward', 'matthewbrown@example.org', 'recruiter'), (69, 'Brian Anderson', 'wcruz@example.org', 'candidate'),  ...
# Jobs: [(4, 'Développeur Python', 'Poste full remote', 'Remote', 1, 1), (5, 'Chargé de Marketing', 'SEO/SEA + contenus', 'Lyon', 2, 2), (6, 'Data Analyst Junior', 'Analyse des données clients', 'Paris', 1, 3), (7, 'Production assistant, television', 'Current serious central cause air feel also. Discover hundred later role.\nDeep capital analysis PM. Program training material stand.', 'Hawkinsmouth', 5, 2), (8, 'Production assistant, television', 'Current serious central cause air feel also. Discover hundred later role.\nDeep capital analysis PM. Program training material stand.', 'Hawkinsmouth', 5, 2), (9, 'Aid worker', 'Base onto off. Reality trade help author ask really.\nWeight mission coach article. Finish start nor. It democratic late network maybe dog.', 'Lake Marcusbury', 1, 2), (10, 'Production assistant, television', 'Current serious central cause air feel also. Discover hundred later role.\nDeep capital analysis PM. Program training material stand.', 'Hawkinsmouth', 5, 2), (11, 'Aid worker', 'Base onto off. Reality trade help author ask really.\nWeight mission coach article. Finish start nor. It democratic late network maybe dog.', 'Lake Marcusbury', 1, 2), (12, 'Doctor, general practice', 'President fly or sense brother strategy once enjoy.\nDesign major same describe professor goal. Change green but clear town network speech. Culture too behavior song life.', 'Joshuaberg', 5, 2), (13, 'Production assistant, television', 'Current serious central cause air feel also. Discover hundred later role.\nDeep capital analysis PM. Program training material stand.', 'Hawkinsmouth', 5, 2), (14, 'Aid worker', 'Base onto off. Reality trade help author ask really.\nWeight mission coach article. Finish start nor. It democratic late network maybe dog.', 'Lake Marcusbury', 1, 2), (15, 'Doctor, general practice', 'President fly or sense brother strategy once enjoy.\nDesign major same describe professor goal. Change green but clear town network speech. Culture too behavior song life.', 'Joshuaberg', 5, 2), (16, 'Herpetologist', 'Section dog who trip cost free compare. Protect month street him dog player else sell.\nMean article risk hand main little left. Last pull four color.\nEmployee of herself. Hour factor would age.', 'West Jamie', 2, 3), (17, 'Production assistant, television', 'Current serious central cause air feel also. Discover hundred later role.\nDeep capital analysis PM. Program training material stand.', 'Hawkinsmouth', 5, 2), (18, 'Aid worker', 'Base onto off. Reality trade help author ask really.\nWeight mission coach article. Finish start nor. It democratic late network maybe dog.', 'Lake Marcusbury', 1, 2), (19, 'Doctor, general practice', 'President fly or sense brother strategy once enjoy.\nDesign major same describe professor goal. Change green but clear town network speech. Culture too behavior song life.', 'Joshuaberg', 5, 2), (20, 'Herpetologist', 'Section dog who trip cost free compare. Protect month street him dog player else sell.\nMean article risk hand main little left. Last pull four color.\nEmployee of herself. Hour factor would age.', 'West Jamie', 2, 3), (21, 'Mudlogger', 'Western specific live allow newspaper suffer. Alone less you case natural section.\nCity wear theory especially similar hit. Current specific job field effort kid.', 'Port Jennifer', 3, 3), (22, 'Textile designer', 'Coach there citizen would leave space. South understand force let.\nAge charge create. Exist unit try majority late plan less seven. Detail suddenly how red.', 'North Jasonton', 2, 3), (23, 'Textile designer', 'Coach there citizen would leave space. South understand force let.\nAge charge create. Exist unit try majority late plan less seven. Detail suddenly how red.', 'North Jasonton', 2, 3), (24, 'Tourist information centre manager', 'Country air last off. Just study continue herself. Hard air arm around get.\nGuess sort change read care different. Newspaper record player it. Wish herself hour little require show body.', ' ...
# Companies: [(1, 'Recrutech', 'Paris'), (2, 'Talentify', 'Lyon'), (3, 'Tech Innovators', 'Paris'), (4, 'Recrutech Solutions', 'Lyon'), (5, 'Talentify', 'Marseille')]
# Categories: [(5, 'Développement Web'), (6, 'Marketing Digital'), (7, 'Data Science'), (8, 'Ressources Humaines'), (9, 'Développement Web'), (10, 'Marketing Digital'), (11, 'Data Science'), (12, 'Ressources Humaines'), (13, 'Développement Web'), (14, 'Marketing Digital'), (15, 'Data Science'), (16, 'Ressources Humaines'), (17, 'Développement Web'), (18, 'Marketing Digital'), (19, 'Data Science'), (20, 'Ressources Humaines'), (21, 'Développement Web'), (22, 'Marketing Digital'), (23, 'Data Science'), (24, 'Ressources Humaines'), (25, 'Développement Web'), (26, 'Marketing Digital'), (27, 'Data Science'), (28, 'Ressources Humaines')]
# Applications: [(3, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (4, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2)), (5, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (6, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2)), (7, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (8, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2)), (9, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (10, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2)), (11, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (12, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2)), (13, 1, 1, 'Je suis passionné par le développement Python.', datetime.date(2025, 7, 1)), (14, 2, 3, 'J’ai une forte appétence pour les données.', datetime.date(2025, 7, 2))]
# applications
# ✅ Data copied sucessful to the bd Jobboard for table applications.
# categories
# ✅ Data copied sucessful to the bd Jobboard for table categories.
# companies
# ✅ Data copied sucessful to the bd Jobboard for table companies.
# jobs
# ✅ Data copied sucessful to the bd Jobboard for table jobs.
# users
# ✅ Data copied sucessful to the bd Jobboard for table users.
# ✅ Connections closed successfully.
